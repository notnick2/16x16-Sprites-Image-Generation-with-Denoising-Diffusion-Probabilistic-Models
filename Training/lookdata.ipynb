# %%
# Load the array from the .npy file
import numpy as np

loaded_array = np.load('sprites_1788_16x16.npy')

print(loaded_array[:5])
# Output:
# [[1 2 3]
#  [4 5 6]]
# Out:
# [[[[255 255 255]
#    [255 255 255]
#    [255 255 255]
#    ...
#    [255 255 255]
#    [255 255 255]
#    [255 255 255]]
#
#   [[255 255 255]
#    [255 255 255]
#    [255 255 255]
#    ...
#    [255 255 255]
#    [255 255 255]
#    [255 255 255]]
#
#   [[255 255 255]
#    [255 255 255]
#    [255 255 255]
#    ...
#    [255 255 255]
#    [255 255 255]
#    [255 255 255]]
#
#   ...
#
#   [[255 255 255]
#    [255 255 255]
#    [255 255 255]
#    ...
#    [255 255 255]
#    [255 255 255]
#    [255 255 255]]
#
#   [[255 255 255]
#    [255 255 255]
#    [255 255 255]
#    ...
#    [255 255 255]
#    [255 255 255]
#    [255 255 255]]
#
#   [[255 255 255]
#    [255 255 255]
#    [255 255 255]
#    ...
#    [255 255 255]
#    [255 255 255]
#    [255 255 255]]]
#
#
#  [[[255 255 255]
#    [255 255 255]
#    [255 255 255]
#    ...
#    [255 255 255]
#    [255 255 255]
#    [255 255 255]]
#
#   [[255 255 255]
#    [255 255 255]
#    [255 255 255]
#    ...
#    [255 255 255]
#    [255 255 255]
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

# Load the dataset (example assumes .npy format)
sprites = np.load('sprites_1788_16x16.npy')

# Display the first sprite
plt.imshow(sprites[0])
plt.show()

# %%
print(sprites[0])
# Out:
# [[[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]
#   [ 99  27  79]
#   [247  67 198]
#   [172  47 138]
#   [172  47 138]
#   [247  67 198]
#   [ 99  27  79]
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]
#   [ 99  27  79]
#   [247  67 198]
#   [172  47 138]
#   [172  47 138]
#   [172  47 138]
#   [172  47 138]
#   [247  67 198]
#   [ 99  27  79]
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   [ 99  27  79]
#   [172  47 138]
#   [172  47 138]
#   [ 74  20  59]
#   [ 74  20  59]
#   [ 74  20  59]
#   [ 74  20  59]
#   [172  47 138]
#   [172  47 138]
#   [ 99  27  79]
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   [ 99  27  79]
#   [172  47 138]
#   [ 74  20  59]
#   [ 74  20  59]
# ...
